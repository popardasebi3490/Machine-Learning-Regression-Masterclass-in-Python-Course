# %% [markdown]
# Libraries import:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2 Import Dataset:

# %%
IceCream = pd.read_csv('IceCreamData.csv')

# %%
#IceCream.head(5)
#IceCream.tail(10)
#IceCream 

IceCream.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.232225   521.570777
# std       8.096388   175.404751
# min       0.000000    10.000000
# 25%      17.122258   405.558681
# 50%      22.392791   529.368565
# 75%      27.740674   642.257922
# max      45.000000  1000.000000

# %%
IceCream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %% [markdown]
# Visualize Dataset:

# %%
sns.jointplot(x = 'Temperature', y = 'Revenue', data = IceCream, color = 'purple')

# %%
sns.pairplot(IceCream)

# %%
sns.lmplot(x = 'Temperature', y = 'Revenue', data = IceCream)

# %% [markdown]
# Creating, testing and training dataset

# %%
x = IceCream[['Temperature']]
x
# Out:
#      Temperature
# 0      24.566884
# 1      26.005191
# 2      27.790554
# 3      20.595335
# 4      11.503498
# ..           ...
# 495    22.274899
# 496    32.893092
# 497    12.588157
# 498    22.362402
# 499    28.957736
#
# [500 rows x 1 columns]

# %%
y = IceCream[['Revenue']]
y
# Out:
#         Revenue
# 0    534.799028
# 1    625.190122
# 2    660.632289
# 3    487.706960
# 4    316.240194
# ..          ...
# 495  524.746364
# 496  755.818399
# 497  306.090719
# 498  566.217304
# 499  655.660388
#
# [500 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 42)

# %%
x_train
# Out:
#      Temperature
# 227    26.944123
# 417    27.516646
# 203    10.447126
# 126    15.992347
# 329    41.924446
# ..           ...
# 106    23.761436
# 270    24.628611
# 348    38.185199
# 435    15.916678
# 102    14.287196
#
# [375 rows x 1 columns]

# %%
x_test
# Out:
#      Temperature
# 361    29.704183
# 73     27.375401
# 374    23.984641
# 155    21.144047
# 104    26.595054
# ..           ...
# 220    24.802577
# 176    21.322392
# 320    15.118197
# 153    19.754708
# 231    20.153345
#
# [125 rows x 1 columns]

# %%
x_train.shape
# Out:
# (375, 1)

# %%
x_test.shape
# Out:
# (125, 1)

# %%
y_train.shape
# Out:
# (375, 1)

# %%
y_test.shape
# Out:
# (125, 1)

# %% [markdown]
# Train the model

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression(fit_intercept = True)
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print('Linear Model Coefficient (m)', regressor.coef_) #.coef pentru m(slope)
print('Linear Model Coefficient (b)', regressor.intercept_) # coeficient
# Out:
# Linear Model Coefficient (m) [[21.37416109]]
# Linear Model Coefficient (b) [46.91078475]

# %% [markdown]
# Test the model

# %%
x_test.shape
# Out:
# (125, 1)

# %%
y_predict = regressor.predict(x_test)

# %%
y_predict
# Out:
# array([[681.81277787],
#        [632.03701584],
#        [559.56236196],
#        [498.84704992],
#        [615.35775421],
#        [304.73607431],
#        [285.81302849],
#        [315.61634521],
#        [506.20253292],
#        [685.57013845],
#        [723.81902231],
#        [400.82303176],
#        [431.58187843],
#        [671.24393513],
#        [ 52.61827778],
#        [198.8274425 ],
#        [523.01806979],
#        [563.82215553],
#        [583.74570895],
#        [682.11913736],
#        [556.14851344],
#        [783.72448213],
#        [655.32484725],
#        [569.988492  ],
#        [912.00834943],
#        [664.6281381 ],
#        [315.97207922],
#        [630.90251298],
#        [730.97303461],
#        [697.89804173],
#        [435.04880926],
#        [471.17165448],
#        [710.15811647],
#        [799.64974714],
#        [640.91056016],
#        [493.60331223],
#        [744.77578087],
#        [318.11532407],
#        [262.71809247],
#        [132.11937313],
# ...

# %%
y_test
# Out:
#         Revenue
# 361  659.873287
# 73   623.248701
# 374  559.135869
# 155  497.752318
# 104  627.901841
# ..          ...
# 220  563.301280
# 176  520.470310
# 320  374.955702
# 153  493.710333
# 231  449.112869
#
# [125 rows x 1 columns]

# %%
plt.scatter(x_train, y_train, color = 'purple')
plt.plot(x_train, regressor.predict(x_train), color = 'green')
plt.ylabel('Revenue [Dollars]')
plt.xlabel('Temperature [DegC]')
plt.title('Revenue Generated vs. Temperature @ Ice Cream Stand (Training set)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature @ Ice Cream Stand (Training set)')

# %%
plt.scatter(x_test, y_test, color = 'blue')
plt.plot(x_test, regressor.predict(x_test), color = 'green')
plt.ylabel('Revenue [Dollars]')
plt.xlabel('Temperature [DegC]')
plt.title('Revenue Generated vs. Temperature @ Ice Cream Stand (Testing set)')
# Out:
# Text(0.5, 1.0, 'Revenue Generated vs. Temperature @ Ice Cream Stand (Testing set)')

# %%
t = [[30]]
revenue = regressor.predict(t)

revenue
# Out:
# c:\Users\LENOVO\anaconda3\envs\machine-learning\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[688.13561744]])
